# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp39-cp39-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 952.4 kB/s eta 0:00:000:01m0:01m
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp39-cp39-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 67.7 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp39-cp39-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 67.8 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: filelock in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch) (3.8.0)
# Requirement already satisfied: typing-extensions in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from torch) (4.5.0)
# Collecting triton==2.0.0
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 26.9 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Downloading https://download.pytorch.org/whl/networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.0 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch) (3.1.2)
# Collecting sympy
#   Downloading https://download.pytorch.org/whl/sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 75.0 MB/s eta 0:00:00:00:0100:01
# Collecting lit
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 18.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting cmake
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 45.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: numpy in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from torchvision) (1.25.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torchvision) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torchvision) (2.10)
# Collecting mpmath>=0.19
#   Downloading https://download.pytorch.org/whl/mpmath-1.2.1-py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.6/532.6 kB 15.7 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90005 sha256=3404f2482505ad7ecdaa0e614613de56fa841935a1e5451cb757b8c14ae14bf3
#   Stored in directory: /home/makinen/.cache/pip/wheels/77/9f/9c/1c3217c66e9f310f11a534c68e168a295d9448999af79d680b
# Successfully built lit
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Installing collected packages: mpmath, lit, cmake, sympy, networkx, triton, torch, torchvision, torchaudio
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Successfully installed cmake-3.25.0 lit-15.0.7 mpmath-1.2.1 networkx-3.0 sympy-1.11.1 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)

# %%
import torch

def format_pytorch_version(version):
  return version.split('+')[0]

TORCH_VERSION = torch.__version__
TORCH = format_pytorch_version(TORCH_VERSION)

print(TORCH)

def format_cuda_version(version):
  return 'cu' + version.replace('.', '')

CUDA_VERSION = torch.version.cuda
CUDA = format_cuda_version(CUDA_VERSION)

print(CUDA)

# !pip install torch-scatter -f https://data.pyg.org/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-{TORCH}+{CUDA}.html
# !pip install torch-geometric

# !pip install --upgrade pip > /dev/null
# Installs the wheel compatible with CUDA 11 and cuDNN 8.2 or newer.
# !pip install "jax[cuda]" -f https://storage.googleapis.com/jax-releases/jax_releases.html
# !pip install jraph
# !pip install flax
# Out:
# 2.0.1
# cu118
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Looking in links: https://data.pyg.org/whl/torch-2.0.1+cu118.html
# Requirement already satisfied: torch-scatter in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (2.1.1+pt20cu118)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Looking in links: https://data.pyg.org/whl/torch-2.0.1+cu118.html
# Requirement already satisfied: torch-sparse in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (0.6.17+pt20cu118)
# Requirement already satisfied: scipy in /home/makinen/.local/lib/python3.9/site-packages (from torch-sparse) (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from scipy->torch-sparse) (1.25.1)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Requirement already satisfied: torch-geometric in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: jinja2 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: pyparsing in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: requests in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from torch-geometric) (2.28.2)
# Requirement already satisfied: scikit-learn in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch-geometric) (0.24.2)
# Requirement already satisfied: numpy in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from torch-geometric) (1.25.1)
# Requirement already satisfied: psutil>=5.8.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch-geometric) (5.9.4)
# Requirement already satisfied: scipy in /home/makinen/.local/lib/python3.9/site-packages (from torch-geometric) (1.10.1)
# Requirement already satisfied: tqdm in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from torch-geometric) (4.62.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from jinja2->torch-geometric) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from requests->torch-geometric) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torch-geometric) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torch-geometric) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: joblib>=0.11 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (2.2.0)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Looking in links: https://storage.googleapis.com/jax-releases/jax_releases.html
# Requirement already satisfied: jax[cuda] in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (0.4.8)
# Requirement already satisfied: scipy>=1.7 in /home/makinen/.local/lib/python3.9/site-packages (from jax[cuda]) (1.10.1)
# Requirement already satisfied: numpy>=1.21 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jax[cuda]) (1.25.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jax[cuda]) (0.0.4)
# Requirement already satisfied: opt-einsum in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from jax[cuda]) (3.3.0)
# Requirement already satisfied: jaxlib==0.4.7+cuda11.cudnn86 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jax[cuda]) (0.4.7+cuda11.cudnn86)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Requirement already satisfied: jraph in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (0.0.6.dev0)
# Requirement already satisfied: numpy>=1.18.0 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jraph) (1.25.1)
# Requirement already satisfied: jax>=0.1.55 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jraph) (0.4.8)
# Requirement already satisfied: jaxlib>=0.1.37 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jraph) (0.4.7+cuda11.cudnn86)
# Requirement already satisfied: opt-einsum in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from jax>=0.1.55->jraph) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /home/makinen/.local/lib/python3.9/site-packages (from jax>=0.1.55->jraph) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jax>=0.1.55->jraph) (0.0.4)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# Requirement already satisfied: flax in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (0.6.8)
# Requirement already satisfied: jax>=0.4.2 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (0.4.8)
# Requirement already satisfied: msgpack in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (1.0.5)
# Requirement already satisfied: optax in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (0.1.4)
# Requirement already satisfied: PyYAML>=5.4.1 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from flax) (6.0)
# Requirement already satisfied: tensorstore in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (0.1.35)
# Requirement already satisfied: typing-extensions>=4.1.1 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (4.5.0)
# Requirement already satisfied: orbax in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (0.1.7)
# Requirement already satisfied: numpy>=1.12 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (1.25.1)
# Requirement already satisfied: rich>=11.1 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from flax) (13.3.3)
# Requirement already satisfied: scipy>=1.7 in /home/makinen/.local/lib/python3.9/site-packages (from jax>=0.4.2->flax) (1.10.1)
# Requirement already satisfied: opt-einsum in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from jax>=0.4.2->flax) (3.3.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from jax>=0.4.2->flax) (0.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from rich>=11.1->flax) (2.13.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from rich>=11.1->flax) (2.2.0)
# Requirement already satisfied: chex>=0.1.5 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from optax->flax) (0.1.7)
# Requirement already satisfied: absl-py>=0.7.1 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from optax->flax) (1.3.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from optax->flax) (0.4.7+cuda11.cudnn86)
# Requirement already satisfied: cached_property in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from orbax->flax) (1.5.2)
# Requirement already satisfied: importlib_resources in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from orbax->flax) (5.12.0)
# Requirement already satisfied: etils in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from orbax->flax) (1.2.0)
# Requirement already satisfied: nest_asyncio in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from orbax->flax) (1.5.6)
# Requirement already satisfied: toolz>=0.9.0 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from chex>=0.1.5->optax->flax) (0.12.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from chex>=0.1.5->optax->flax) (0.1.8)
# Requirement already satisfied: mdurl~=0.1 in /automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=11.1->flax) (0.1.2)
# Requirement already satisfied: zipp>=3.1.0 in /softs/intelpython/intelpython3-2022.2.1.17274/intelpython/python3.9/lib/python3.9/site-packages (from importlib_resources->orbax->flax) (3.10.0)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -umpy (/automnt/data101/makinen/venvs/fastjax/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
import functools
import jax
import jax.numpy as jnp
import time
import jraph
import flax
import optax
import pickle
import numpy as np
import torch

from torch_geometric.data import Data, Dataset
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset

from flax import linen as nn
from flax.training import train_state
import pathlib
import csv
import time
import os
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
